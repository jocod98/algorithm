# %%
import csv

# %%
f = open("middle.csv",encoding = 'utf-8')

# %%
data = csv.reader(f)

# %%
data

# %%
for  row in data:
    print(row)
# Out:
# ['\ufeffB331356', '0']
# ['B431011', '62']
# ['B431347', '19']
# ['B611002', '93']
# ['B631021', '85']
# ['B631065', '32']
# ['B631067', '0']
# ['B631077', '96']
# ['B631079', '88']
# ['B631109', '45']
# ['B631116', '90']
# ['B631124', '93']
# ['B631133', '69']
# ['B631146', '46']
# ['B631149', '50']
# ['B631180', '73']
# ['B631192', '35']
# ['B631219', '79']
# ['B631220', '93']
# ['B631225', '90']
# ['B631253', '86']
# ['B635083', '69']
# ['B635131', '84']
# ['B635171', '58']
# ['B635194', '90']
# ['B635290', '63']
# ['B635398', '35']
# ['B635436', '18']
# ['B673014', '9']
# ['B673026', '17']
# ['B693199', '73']
# ['B698093', '75']
# ['B731004', '72']
# ['B731005', '83']
# ['B731026', '47']
# ['B731035', '0']
# ['B731037', '88']
# ['B731038', '47']
# ['B731079', '91']
# ['B731087', '56']
# ['B731095', '75']
# ['B731105', '50']
# ['B731106', '88']
# ['B731110', '62']
# ['B731126', '56']
# ['B731128', '68']
# ['B731164', '68']
# ['B731171', '21']
# ['B731180', '69']
# ...

# %%
header = next(data)
print(header)
# Out:
# ['B431011', '62']
